# %%
import random

word_list = ['amazing', 'tornado', 'cyclone', 'melodious', 'keyboard', 'computer', 'micromax','kurkure','outstanding','jupyter','airforce','satelite','mathematics','architect','engineer','musician','timetable','battery','presentation','bollywood','comfortable','something','understanding','suitcase']
secret_word = random.choice(word_list)


def replace_letter(letter):
     for i in range(len(secret_word)):
                if guess == secret_word[i]:
                    out_list[i] = guess

    
out_list = ['?' for i in range(len(secret_word))]

print("\n\n****************** NINE LIVES GAME ****************\n\n")

name = input("What's your name :").strip()
if len(name) == 0:
    name = input("your name is empty, enter again : ").strip()
if (name.isalpha())==0:
    name = input("Enter a valid name : ").strip()
    
print("\n\n-------------- WELCOME TO THE GAME ",name.upper()," , ALL THE BEST -------------")


no_of_lives = 9
guess_list = []

while(1):
    
    if no_of_lives == 0:
        print("\n\n--------------- SORRY",name,"!! GAME OVER!! YOU ARE OUT OF LIVES!! --------------")
        break
    
    print("\n\n",out_list,"\n\n Lives Left : ","\U0001F493"*no_of_lives,"\n")
    guess = input("Guess a letter or the whole word : ").strip().lower()
    
    if guess in guess_list:
        print("\nThe letter is already guessed.")
        continue
        
    guess_list.append(guess)
    
    if len(guess) == 1:
        
        if guess in secret_word:
            replace_letter(guess)
            print("--------------------------------------------------------------")
            out_list_str = ''.join(out_list)
            if out_list_str == secret_word:
                print("\n\n--------------- \U0001F973 YOU WON , the secret word was : ",secret_word," \U0001F973 ---------------")
                break
            
        else:
            print("\nIncorrect guess. You lose a life.")
            no_of_lives-=1 
            print("--------------------------------------------------------------")
            
    else:
        if guess == secret_word:
            print("\n\n--------------- \U0001F973 YOU WON ",name,", the secret word was : ",secret_word," \U0001F973 ---------------")
            break

        else:
            print("\nIncorrect guess. You lose a life.")
            no_of_lives-=1 
            print("--------------------------------------------------------------")
# Out:
# ****************** NINE LIVES GAME ****************
#
#
# What's your name :menu
#
#
# -------------- WELCOME TO THE GAME  MENU  , ALL THE BEST -------------
#
#
#  ['?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
#
#  Lives Left :  💓💓💓💓💓💓💓💓💓
#
# Guess a letter or the whole word : o
#
# Incorrect guess. You lose a life.
# --------------------------------------------------------------
#
#
#  ['?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
#
#  Lives Left :  💓💓💓💓💓💓💓💓
#
# Guess a letter or the whole word : a
# --------------------------------------------------------------
#
#
#  ['?', 'a', '?', '?', '?', '?', 'a', '?', '?', '?', '?']
#
#  Lives Left :  💓💓💓💓💓💓💓💓
#
# Guess a letter or the whole word : e
# --------------------------------------------------------------
#
#
#  ['?', 'a', '?', '?', 'e', '?', 'a', '?', '?', '?', '?']
#
#  Lives Left :  💓💓💓💓💓💓💓💓
#
# Guess a letter or the whole word : s
# --------------------------------------------------------------
#
#
# ...
